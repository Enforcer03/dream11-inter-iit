# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from tqdm import tqdm
import cricketstats as cks

# %%
search = cks.cricketstats.search(allplayers=True)

# %%
database ="/Users/ayush_arya/Downloads/Inter_IIT_Tech_13/dream11-inter-iit/all_json.zip"
from_date = (2024, 8, 1) # The (Year, Month, Day) from which to start search
to_date = (2024, 11, 10) # The (Year, Month, Day) from which to end search
matchtype = ["ODI"] # Options: ["Test", "MDM", "ODI", "ODM", "T20", "IT20"] Explanation of what these mean is found at https://cricsheet.org/downloads/

# %%
# Optional Arguments:
# First we can set overs and innings related arguments:
betweenovers=[] # Search only these overs. eg. betweenovers = [1, 20]. Or if you only want to search for powerplays that are mandatory and option input "powerplays" eg. betweenovers =["powerplays"]
innings=[] # Search these innings. Options: 1, 2, 3, 4 eg. innings = [1,3]
fielders=[] # Search bowling stats involves these fielders.
oppositionbatters=[] # Search overs where players have bowled against certain batters. Options: batter names. You can also put in a list of batters by handedness. eg. oppositionbatters=["Left hand", "Right Hand"]
oppositionbowlers=[] # Search overs where players have batted against certain bowlers Options: bowler names You can also put in list of bowlers by type, eg. oppositionbowlers=["Right arm pace","Left arm pace","Right arm Off break","Right arm Leg break","Left arm orthodox","Left arm wrist spin"]
superover=None # Search normal innings or superover innings. Options: True, False eg. superover=True
battingposition=[] # Search stats at certain position in batting order. eg. battingposition=[1,2,3]
bowlingposition=[] # Search stats at certain position in bowling order. eg. bowlingposition=[1,2]

# Second we have match related arguments
sex=[] # Search only matches of certain sex. Options: "male", "female" eg. sex = ["female"] 
playerteams=[] # Search matches where players have played in certain teams. Options: team names eg. playerteams=["Australia", "England"]
teammates=[] # Search matches where certain teammates play. For this to work playerteams must be populated.
oppositionteams=[] # Search matches where opposition is only certain teams. Options: team names eg. oppositionteams=["India", "England"]
venue=[] # Search matches played only at these venues Options: Cricket Grounds eg. venue=["Sydney Cricket Ground", "Melbourne Cricket Ground", ""Brisbane Cricket Ground, Woolloongabba""]
teamtype=[] # Search only for particualr type of teams. eg. "international", "club".
event=[] # Search matches played as part of these Leagues or Tournaments Options: Name of League or Tournament eg. event=["Sheffield Shield", "ICC World Cup", "Big Bash League"] 
matchresult=None # Search matches where players or teams have these results. When looking at players, this option **must** be used with at one team in playersteams variable. Options either "won" or "loss" or "draw" or "tie" eg. matchresult="won"
sumstats=False # When switched to True, it adds an "all players" or "all teams" row at end of result that sums all players or teams stats that are searched for.

# %%
search.stats(database, from_date, to_date, matchtype, betweenovers=betweenovers, innings=innings, sex=sex, playersteams=playerteams, oppositionbatters=oppositionbatters, oppositionbowlers=oppositionbowlers, oppositionteams=oppositionteams, venue=venue, event=event, matchresult=matchresult, superover=superover, battingposition=battingposition, bowlingposition=bowlingposition, fielders=fielders, sumstats=sumstats)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 25/25 [00:01<00:00, 13.77it/s]

# %%
one_day_data = search.inningsresult
one_day_data
# Out:
#                                                 MatchID  \
# 0                   Sri_Lanka-India-2024-08-02-male-ODI
# 1                   Sri_Lanka-India-2024-08-02-male-ODI
# 2                   Sri_Lanka-India-2024-08-02-male-ODI
# 3                   Sri_Lanka-India-2024-08-02-male-ODI
# 4                   Sri_Lanka-India-2024-08-02-male-ODI
# ...                                                 ...
# 1891  United_Arab_Emirates-Netherlands-2024-11-03-ma...
# 1892  United_Arab_Emirates-Netherlands-2024-11-03-ma...
# 1893  United_Arab_Emirates-Netherlands-2024-11-03-ma...
# 1894  United_Arab_Emirates-Netherlands-2024-11-03-ma...
# 1895  United_Arab_Emirates-Netherlands-2024-11-03-ma...
#
#                                               InningsID       Date  Year  \
# 0                 Sri_Lanka-India-2024-08-02-male-ODI-1 2024-08-02  2024
# 1                 Sri_Lanka-India-2024-08-02-male-ODI-1 2024-08-02  2024
# 2                 Sri_Lanka-India-2024-08-02-male-ODI-1 2024-08-02  2024
# 3                 Sri_Lanka-India-2024-08-02-male-ODI-1 2024-08-02  2024
# 4                 Sri_Lanka-India-2024-08-02-male-ODI-1 2024-08-02  2024
# ...                                                 ...        ...   ...
# 1891  United_Arab_Emirates-Netherlands-2024-11-03-ma... 2024-11-03  2024
# 1892  United_Arab_Emirates-Netherlands-2024-11-03-ma... 2024-11-03  2024
# 1893  United_Arab_Emirates-Netherlands-2024-11-03-ma... 2024-11-03  2024
# 1894  United_Arab_Emirates-Netherlands-2024-11-03-ma... 2024-11-03  2024
# 1895  United_Arab_Emirates-Netherlands-2024-11-03-ma... 2024-11-03  2024
#
#       Month Match Type                                              Venue  \
# 0         8        ODI                       R Premadasa Stadium, Colombo
# 1         8        ODI                       R Premadasa Stadium, Colombo
# 2         8        ODI                       R Premadasa Stadium, Colombo
# 3         8        ODI                       R Premadasa Stadium, Colombo
# 4         8        ODI                       R Premadasa Stadium, Colombo
# ...     ...        ...                                                ...
# 1891     11        ODI  Al Amerat Cricket Ground Oman Cricket (Ministr...
# 1892     11        ODI  Al Amerat Cricket Ground Oman Cricket (Ministr...
# 1893     11        ODI  Al Amerat Cricket Ground Oman Cricket (Ministr...
# 1894     11        ODI  Al Amerat Cricket Ground Oman Cricket (Ministr...
# 1895     11        ODI  Al Amerat Cricket Ground Oman Cricket (Ministr...
#
#                                      Event          Match Winner  \
# 0                  India tour of Sri Lanka                  None
# 1                  India tour of Sri Lanka                  None
# 2                  India tour of Sri Lanka                  None
# 3                  India tour of Sri Lanka                  None
# 4                  India tour of Sri Lanka                  None
# ...                                    ...                   ...
# 1891  ICC Men's Cricket World Cup League 2  United Arab Emirates
# 1892  ICC Men's Cricket World Cup League 2  United Arab Emirates
# 1893  ICC Men's Cricket World Cup League 2  United Arab Emirates
# 1894  ICC Men's Cricket World Cup League 2  United Arab Emirates
# 1895  ICC Men's Cricket World Cup League 2  United Arab Emirates
#
#                 Player  ... Runsgiven Wickets  Overs Bowled Balls Bowled  \
# 0           P Nissanka  ...       NaN     NaN           NaN          NaN
# 1         WIA Fernando  ...       NaN     NaN           NaN          NaN
# 2           BKG Mendis  ...       NaN     NaN           NaN          NaN
# 3     S Samarawickrama  ...       NaN     NaN           NaN          NaN
# 4         KIC Asalanka  ...       NaN     NaN           NaN          NaN
# ...                ...  ...       ...     ...           ...          ...
# 1891  RE van der Merwe  ...       NaN     NaN           NaN          NaN
# 1892  T van der Gugten  ...       NaN     NaN           NaN          NaN
# 1893            A Dutt  ...       NaN     NaN           NaN          NaN
# 1894          M Levitt  ...       NaN     NaN           NaN          NaN
# 1895   PA van Meekeren  ...       NaN     NaN           NaN          NaN
#
#       Economy Rate  Bowling Avg Avg Consecutive Dot Balls Bowling S/R  \
# 0              NaN          NaN                       NaN         NaN
# 1              NaN          NaN                       NaN         NaN
# 2              NaN          NaN                       NaN         NaN
# 3              NaN          NaN                       NaN         NaN
# 4              NaN          NaN                       NaN         NaN
# ...            ...          ...                       ...         ...
# 1891           NaN          NaN                       NaN         NaN
# 1892           NaN          NaN                       NaN         NaN
# 1893           NaN          NaN                       NaN         NaN
# 1894           NaN          NaN                       NaN         NaN
# 1895           NaN          NaN                       NaN         NaN
#
#       Runsgiven/Ball  Batting S/R AA
# 0                NaN         6.69675
# 1                NaN       -53.68325
# 2                NaN       -22.81325
# 3                NaN       -23.53325
# 4                NaN        -1.30325
# ...              ...             ...
# 1891             NaN         8.94675
# 1892             NaN        27.67675
# 1893             NaN       -51.30325
# 1894             NaN        52.02675
# 1895             NaN         7.02675
#
# [1896 rows x 46 columns]

# %%
one_day_data.to_csv("one_day_data.csv")
